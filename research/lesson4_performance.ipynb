# %% [markdown]
# Performance & Optimization in PySpark. This lesson gives the practical patterns you’ll use most as a senior data scientist: partitioning, caching, shuffle-aware joins, file-format tips, and tools to inspect/measure performance.
#
# I’ll explain concepts first, then show concise, runnable code (a new file you can drop into your repo) with detailed comments so you can run experiments locally and push to GitHub.

# %%
"""
Lesson 4: Performance & Optimization Examples (PySpark)
-------------------------------------------------------
Run:
    source venv/bin/activate
    python src/lesson4_performance.py

This script demonstrates:
 - inspecting / changing partitions
 - caching/persisting
 - explain() plans
 - broadcast joins
 - repartition vs coalesce
 - writing parquet with good partitioning
"""

from pathlib import Path
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.functions import broadcast
import urllib.request

# ---------------------------
# 1) Setup SparkSession
# ---------------------------
# ---------------------------
# 1) Setup SparkSession
# ---------------------------
spark = (
    SparkSession.builder
    .appName("lesson4-performance")
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", "8")  # adjust for local dev
    .getOrCreate()
)

print("Spark version:", spark.version)
print("spark.sql.shuffle.partitions =", spark.conf.get("spark.sql.shuffle.partitions"))
print("-" * 60)

# ---------------------------
# 2) Download small dataset (Iris) and create a larger DF for experiments
# ---------------------------
iris_url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
local_path = Path("/tmp/iris.csv")
urllib.request.urlretrieve(iris_url, str(local_path))

# read once
iris_df = spark.read.csv(str(local_path), header=True, inferSchema=True)

# Create a bigger dataset by repeating iris_df several times (to simulate larger data)
# Note: for real benchmarks use large public datasets (NYC taxi, etc.)
big_df = iris_df
REPEATS = 200  # increase to simulate larger dataset; keeps memory use moderate locally
for i in range(REPEATS - 1):
    big_df = big_df.union(iris_df)

print("Estimated rows (approx):", big_df.count())
print("Partitions (initial):", big_df.rdd.getNumPartitions())
print("-" * 60)

# ---------------------------
# 3) Repartition vs Coalesce
# ---------------------------
print("-> Repartitioning to 16 partitions (causes shuffle)")
big_repart = big_df.repartition(16)
print("Partitions after repartition:", big_repart.rdd.getNumPartitions())

print("-> Coalescing to 4 partitions (no full shuffle, may move data unevenly)")
big_coalesce = big_repart.coalesce(4)
print("Partitions after coalesce:", big_coalesce.rdd.getNumPartitions())
print("-" * 60)

# ---------------------------
# 4) Caching / Persisting
# ---------------------------
# Use caching when you plan to re-use the same DataFrame multiple times.
print("-> Caching big_coalesce")
big_coalesce.cache()  # default MEMORY_ONLY
# Trigger cache materialization via an action
print("Count (materialize cache):", big_coalesce.count())

# Now repeated actions are faster (avoid re-compute)
print("Count again (should be faster):", big_coalesce.count())
print("-" * 60)

# ---------------------------
# 5) Explain plan: check for shuffles, broadcasts
# ---------------------------
# Simple aggregation (should cause shuffle due to groupBy)
agg = big_coalesce.groupBy("species").agg(
    F.count("*").alias("cnt"),
    F.avg("sepal_length").alias("avg_sepal_len")
)
print("Explain plan for aggregation (logical and physical):")
agg.explain(extended=True)  # extended True prints analyzed, optimized, physical plan
print("-" * 60)

# ---------------------------
# 6) Broadcast join example
# ---------------------------
# Create a small lookup table and join. Broadcast the small DF to avoid shuffle on join.
species_lookup = spark.createDataFrame(
    [("setosa", "short petals"), ("versicolor", "medium petals"), ("virginica", "long petals")],
    ["species", "description"]
)

# Use broadcast() to force a broadcast join (avoids shuffle)
joined = big_coalesce.join(broadcast(species_lookup), on="species", how="inner")
print("Explain plan for broadcast join (should include BroadcastHashJoin):")
joined.select("species", "description").explain()
print("-" * 60)

# ---------------------------
# 7) Skew mitigation (pattern)
# ---------------------------
# If one key is very heavy (skew), you can salt the key:
# df.withColumn("salt", F.expr("floor(rand() * N)")) then join on (key, salt) after duplicating small DF etc.
print("Skew mitigation pattern: add 'salt' to keys to spread large-key loads across partitions.")
print("Example (not executed heavy):")
print("""
# pseudo:
from pyspark.sql.functions import floor, rand
N = 10  # number of salts
big_salted = big_coalesce.withColumn('salt', floor(rand() * N))
small_salted = small_df.withColumn('salt', F.lit(0))  # or replicate small_df for salt range
# join on both key and salt
""")
print("-" * 60)

# ---------------------------
# 8) Predicate pushdown & writing parquet
# ---------------------------
# Save to parquet partitioned by 'species' (good for queries filtering by species)
output_parquet = "output/iris_parquet_partitioned"
print(f"Writing partitioned parquet to {output_parquet} (this will create one folder per species)")
joined.write.mode("overwrite").partitionBy("species").parquet(output_parquet)

# Read back with predicate pushdown (only species=setosa will be scanned)
print("Read back with predicate pushdown - only scans partition setosa")
subset = spark.read.parquet(output_parquet).filter(F.col("species") == "setosa")
print("Explain plan for filtered read (should show PartitionFilters):")
subset.explain()
print("Subset count (should be small):", subset.count())
print("-" * 60)

# ---------------------------
# 9) Checkpointing (for very long lineage)
# ---------------------------
# If your lineage graph becomes very long (many transformations), use checkpointing to truncate lineage.
# Requires setting a checkpoint dir on HDFS or local FS for local dev.
spark.sparkContext.setCheckpointDir("/tmp/spark-checkpoint")
short_df = big_coalesce.checkpoint(eager=True)  # truncates lineage immediately
print("Checkpoint done. Partitions:", short_df.rdd.getNumPartitions())
print("-" * 60)

# ---------------------------
# 10) Cleanup: unpersist and stop
# ---------------------------
big_coalesce.unpersist()
spark.stop()
print("Done. Spark stopped.")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/08 11:26:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Spark version: 3.5.7
# spark.sql.shuffle.partitions = 8
# ------------------------------------------------------------
# Estimated rows (approx): 30000
# Partitions (initial): 200
# ------------------------------------------------------------
# -> Repartitioning to 16 partitions (causes shuffle)
# [Stage 5:==================================================>   (187 + 13) / 200]
# Partitions after repartition: 16
# -> Coalescing to 4 partitions (no full shuffle, may move data unevenly)
# [Stage 6:=================================================>    (184 + 16) / 200]
# Partitions after coalesce: 4
# ------------------------------------------------------------
# -> Caching big_coalesce
# Count (materialize cache): 30000
# Count again (should be faster): 30000
# ------------------------------------------------------------
# Explain plan for aggregation (logical and physical):
# == Parsed Logical Plan ==
# 'Aggregate ['species], ['species, count(1) AS cnt#6328L, avg('sepal_length) AS avg_sepal_len#6330]
# +- Repartition 4, false
#    +- Repartition 16, true
#       +- Union false, false
#          :- Relation [sepal_length#17,sepal_width#18,petal_length#19,petal_width#20,species#21] csv
#          :- Relation [sepal_length#27,sepal_width#28,petal_length#29,petal_width#30,species#31] csv
#          :- Relation [sepal_length#37,sepal_width#38,petal_length#39,petal_width#40,species#41] csv
#          :- Relation [sepal_length#47,sepal_width#48,petal_length#49,petal_width#50,species#51] csv
#          :- Relation [sepal_length#57,sepal_width#58,petal_length#59,petal_width#60,species#61] csv
#          :- Relation [sepal_length#67,sepal_width#68,petal_length#69,petal_width#70,species#71] csv
#          :- Relation [sepal_length#77,sepal_width#78,petal_length#79,petal_width#80,species#81] csv
#          :- Relation [sepal_length#87,sepal_width#88,petal_length#89,petal_width#90,species#91] csv
#          :- Relation [sepal_length#97,sepal_width#98,petal_length#99,petal_width#100,species#101] csv
#          :- Relation [sepal_length#107,sepal_width#108,petal_length#109,petal_width#110,species#111] csv
#          :- Relation [sepal_length#117,sepal_width#118,petal_length#119,petal_width#120,species#121] csv
#          :- Relation [sepal_length#127,sepal_width#128,petal_length#129,petal_width#130,species#131] csv
#          :- Relation [sepal_length#137,sepal_width#138,petal_length#139,petal_width#140,species#141] csv
#          :- Relation [sepal_length#147,sepal_width#148,petal_length#149,petal_width#150,species#151] csv
#          :- Relation [sepal_length#157,sepal_width#158,petal_length#159,petal_width#160,species#161] csv
#          :- Relation [sepal_length#167,sepal_width#168,petal_length#169,petal_width#170,species#171] csv
#          :- Relation [sepal_length#177,sepal_width#178,petal_length#179,petal_width#180,species#181] csv
#          :- Relation [sepal_length#187,sepal_width#188,petal_length#189,petal_width#190,species#191] csv
#          :- Relation [sepal_length#197,sepal_width#198,petal_length#199,petal_width#200,species#201] csv
#          :- Relation [sepal_length#207,sepal_width#208,petal_length#209,petal_width#210,species#211] csv
#          :- Relation [sepal_length#217,sepal_width#218,petal_length#219,petal_width#220,species#221] csv
#          :- Relation [sepal_length#227,sepal_width#228,petal_length#229,petal_width#230,species#231] csv
#          :- Relation [sepal_length#237,sepal_width#238,petal_length#239,petal_width#240,species#241] csv
#          :- Relation [sepal_length#247,sepal_width#248,petal_length#249,petal_width#250,species#251] csv
#          :- Relation [sepal_length#257,sepal_width#258,petal_length#259,petal_width#260,species#261] csv
#          :- Relation [sepal_length#267,sepal_width#268,petal_length#269,petal_width#270,species#271] csv
#          :- Relation [sepal_length#277,sepal_width#278,petal_length#279,petal_width#280,species#281] csv
#          :- Relation [sepal_length#287,sepal_width#288,petal_length#289,petal_width#290,species#291] csv
#          :- Relation [sepal_length#297,sepal_width#298,petal_length#299,petal_width#300,species#301] csv
#          :- Relation [sepal_length#307,sepal_width#308,petal_length#309,petal_width#310,species#311] csv
#          :- Relation [sepal_length#317,sepal_width#318,petal_length#319,petal_width#320,species#321] csv
#          :- Relation [sepal_length#327,sepal_width#328,petal_length#329,petal_width#330,species#331] csv
#          :- Relation [sepal_length#337,sepal_width#338,petal_length#339,petal_width#340,species#341] csv
#          :- Relation [sepal_length#347,sepal_width#348,petal_length#349,petal_width#350,species#351] csv
#          :- Relation [sepal_length#357,sepal_width#358,petal_length#359,petal_width#360,species#361] csv
#          :- Relation [sepal_length#367,sepal_width#368,petal_length#369,petal_width#370,species#371] csv
#          :- Relation [sepal_length#377,sepal_width#378,petal_length#379,petal_width#380,species#381] csv
#          :- Relation [sepal_length#387,sepal_width#388,petal_length#389,petal_width#390,species#391] csv
#          :- Relation [sepal_length#397,sepal_width#398,petal_length#399,petal_width#400,species#401] csv
#          :- Relation [sepal_length#407,sepal_width#408,petal_length#409,petal_width#410,species#411] csv
#          :- Relation [sepal_length#417,sepal_width#418,petal_length#419,petal_width#420,species#421] csv
#          :- Relation [sepal_length#427,sepal_width#428,petal_length#429,petal_width#430,species#431] csv
#          :- Relation [sepal_length#437,sepal_width#438,petal_length#439,petal_width#440,species#441] csv
#          :- Relation [sepal_length#447,sepal_width#448,petal_length#449,petal_width#450,species#451] csv
#          :- Relation [sepal_length#457,sepal_width#458,petal_length#459,petal_width#460,species#461] csv
#          :- Relation [sepal_length#467,sepal_width#468,petal_length#469,petal_width#470,species#471] csv
#          :- Relation [sepal_length#477,sepal_width#478,petal_length#479,petal_width#480,species#481] csv
#          :- Relation [sepal_length#487,sepal_width#488,petal_length#489,petal_width#490,species#491] csv
#          :- Relation [sepal_length#497,sepal_width#498,petal_length#499,petal_width#500,species#501] csv
#          :- Relation [sepal_length#507,sepal_width#508,petal_length#509,petal_width#510,species#511] csv
#          :- Relation [sepal_length#517,sepal_width#518,petal_length#519,petal_width#520,species#521] csv
#          :- Relation [sepal_length#527,sepal_width#528,petal_length#529,petal_width#530,species#531] csv
#          :- Relation [sepal_length#537,sepal_width#538,petal_length#539,petal_width#540,species#541] csv
#          :- Relation [sepal_length#547,sepal_width#548,petal_length#549,petal_width#550,species#551] csv
#          :- Relation [sepal_length#557,sepal_width#558,petal_length#559,petal_width#560,species#561] csv
#          :- Relation [sepal_length#567,sepal_width#568,petal_length#569,petal_width#570,species#571] csv
#          :- Relation [sepal_length#577,sepal_width#578,petal_length#579,petal_width#580,species#581] csv
#          :- Relation [sepal_length#587,sepal_width#588,petal_length#589,petal_width#590,species#591] csv
#          :- Relation [sepal_length#597,sepal_width#598,petal_length#599,petal_width#600,species#601] csv
#          :- Relation [sepal_length#607,sepal_width#608,petal_length#609,petal_width#610,species#611] csv
#          :- Relation [sepal_length#617,sepal_width#618,petal_length#619,petal_width#620,species#621] csv
#          :- Relation [sepal_length#627,sepal_width#628,petal_length#629,petal_width#630,species#631] csv
#          :- Relation [sepal_length#637,sepal_width#638,petal_length#639,petal_width#640,species#641] csv
#          :- Relation [sepal_length#647,sepal_width#648,petal_length#649,petal_width#650,species#651] csv
#          :- Relation [sepal_length#657,sepal_width#658,petal_length#659,petal_width#660,species#661] csv
#          :- Relation [sepal_length#667,sepal_width#668,petal_length#669,petal_width#670,species#671] csv
#          :- Relation [sepal_length#677,sepal_width#678,petal_length#679,petal_width#680,species#681] csv
#          :- Relation [sepal_length#687,sepal_width#688,petal_length#689,petal_width#690,species#691] csv
#          :- Relation [sepal_length#697,sepal_width#698,petal_length#699,petal_width#700,species#701] csv
#          :- Relation [sepal_length#707,sepal_width#708,petal_length#709,petal_width#710,species#711] csv
#          :- Relation [sepal_length#717,sepal_width#718,petal_length#719,petal_width#720,species#721] csv
#          :- Relation [sepal_length#727,sepal_width#728,petal_length#729,petal_width#730,species#731] csv
#          :- Relation [sepal_length#737,sepal_width#738,petal_length#739,petal_width#740,species#741] csv
#          :- Relation [sepal_length#747,sepal_width#748,petal_length#749,petal_width#750,species#751] csv
#          :- Relation [sepal_length#757,sepal_width#758,petal_length#759,petal_width#760,species#761] csv
#          :- Relation [sepal_length#767,sepal_width#768,petal_length#769,petal_width#770,species#771] csv
#          :- Relation [sepal_length#777,sepal_width#778,petal_length#779,petal_width#780,species#781] csv
#          :- Relation [sepal_length#787,sepal_width#788,petal_length#789,petal_width#790,species#791] csv
#          :- Relation [sepal_length#797,sepal_width#798,petal_length#799,petal_width#800,species#801] csv
#          :- Relation [sepal_length#807,sepal_width#808,petal_length#809,petal_width#810,species#811] csv
#          :- Relation [sepal_length#817,sepal_width#818,petal_length#819,petal_width#820,species#821] csv
#          :- Relation [sepal_length#827,sepal_width#828,petal_length#829,petal_width#830,species#831] csv
#          :- Relation [sepal_length#837,sepal_width#838,petal_length#839,petal_width#840,species#841] csv
#          :- Relation [sepal_length#847,sepal_width#848,petal_length#849,petal_width#850,species#851] csv
#          :- Relation [sepal_length#857,sepal_width#858,petal_length#859,petal_width#860,species#861] csv
#          :- Relation [sepal_length#867,sepal_width#868,petal_length#869,petal_width#870,species#871] csv
#          :- Relation [sepal_length#877,sepal_width#878,petal_length#879,petal_width#880,species#881] csv
#          :- Relation [sepal_length#887,sepal_width#888,petal_length#889,petal_width#890,species#891] csv
#          :- Relation [sepal_length#897,sepal_width#898,petal_length#899,petal_width#900,species#901] csv
#          :- Relation [sepal_length#907,sepal_width#908,petal_length#909,petal_width#910,species#911] csv
#          :- Relation [sepal_length#917,sepal_width#918,petal_length#919,petal_width#920,species#921] csv
#          :- Relation [sepal_length#927,sepal_width#928,petal_length#929,petal_width#930,species#931] csv
#          :- Relation [sepal_length#937,sepal_width#938,petal_length#939,petal_width#940,species#941] csv
#          :- Relation [sepal_length#947,sepal_width#948,petal_length#949,petal_width#950,species#951] csv
#          :- Relation [sepal_length#957,sepal_width#958,petal_length#959,petal_width#960,species#961] csv
#          :- Relation [sepal_length#967,sepal_width#968,petal_length#969,petal_width#970,species#971] csv
#          :- Relation [sepal_length#977,sepal_width#978,petal_length#979,petal_width#980,species#981] csv
#          :- Relation [sepal_length#987,sepal_width#988,petal_length#989,petal_width#990,species#991] csv
#          :- Relation [sepal_length#997,sepal_width#998,petal_length#999,petal_width#1000,species#1001] csv
#          :- Relation [sepal_length#1007,sepal_width#1008,petal_length#1009,petal_width#1010,species#1011] csv
#          :- Relation [sepal_length#1017,sepal_width#1018,petal_length#1019,petal_width#1020,species#1021] csv
#          :- Relation [sepal_length#1027,sepal_width#1028,petal_length#1029,petal_width#1030,species#1031] csv
#          :- Relation [sepal_length#1037,sepal_width#1038,petal_length#1039,petal_width#1040,species#1041] csv
#          :- Relation [sepal_length#1047,sepal_width#1048,petal_length#1049,petal_width#1050,species#1051] csv
#          :- Relation [sepal_length#1057,sepal_width#1058,petal_length#1059,petal_width#1060,species#1061] csv
#          :- Relation [sepal_length#1067,sepal_width#1068,petal_length#1069,petal_width#1070,species#1071] csv
#          :- Relation [sepal_length#1077,sepal_width#1078,petal_length#1079,petal_width#1080,species#1081] csv
#          :- Relation [sepal_length#1087,sepal_width#1088,petal_length#1089,petal_width#1090,species#1091] csv
#          :- Relation [sepal_length#1097,sepal_width#1098,petal_length#1099,petal_width#1100,species#1101] csv
#          :- Relation [sepal_length#1107,sepal_width#1108,petal_length#1109,petal_width#1110,species#1111] csv
#          :- Relation [sepal_length#1117,sepal_width#1118,petal_length#1119,petal_width#1120,species#1121] csv
#          :- Relation [sepal_length#1127,sepal_width#1128,petal_length#1129,petal_width#1130,species#1131] csv
#          :- Relation [sepal_length#1137,sepal_width#1138,petal_length#1139,petal_width#1140,species#1141] csv
#          :- Relation [sepal_length#1147,sepal_width#1148,petal_length#1149,petal_width#1150,species#1151] csv
#          :- Relation [sepal_length#1157,sepal_width#1158,petal_length#1159,petal_width#1160,species#1161] csv
#          :- Relation [sepal_length#1167,sepal_width#1168,petal_length#1169,petal_width#1170,species#1171] csv
#          :- Relation [sepal_length#1177,sepal_width#1178,petal_length#1179,petal_width#1180,species#1181] csv
#          :- Relation [sepal_length#1187,sepal_width#1188,petal_length#1189,petal_width#1190,species#1191] csv
#          :- Relation [sepal_length#1197,sepal_width#1198,petal_length#1199,petal_width#1200,species#1201] csv
#          :- Relation [sepal_length#1207,sepal_width#1208,petal_length#1209,petal_width#1210,species#1211] csv
#          :- Relation [sepal_length#1217,sepal_width#1218,petal_length#1219,petal_width#1220,species#1221] csv
#          :- Relation [sepal_length#1227,sepal_width#1228,petal_length#1229,petal_width#1230,species#1231] csv
#          :- Relation [sepal_length#1237,sepal_width#1238,petal_length#1239,petal_width#1240,species#1241] csv
#          :- Relation [sepal_length#1247,sepal_width#1248,petal_length#1249,petal_width#1250,species#1251] csv
#          :- Relation [sepal_length#1257,sepal_width#1258,petal_length#1259,petal_width#1260,species#1261] csv
#          :- Relation [sepal_length#1267,sepal_width#1268,petal_length#1269,petal_width#1270,species#1271] csv
#          :- Relation [sepal_length#1277,sepal_width#1278,petal_length#1279,petal_width#1280,species#1281] csv
#          :- Relation [sepal_length#1287,sepal_width#1288,petal_length#1289,petal_width#1290,species#1291] csv
#          :- Relation [sepal_length#1297,sepal_width#1298,petal_length#1299,petal_width#1300,species#1301] csv
#          :- Relation [sepal_length#1307,sepal_width#1308,petal_length#1309,petal_width#1310,species#1311] csv
#          :- Relation [sepal_length#1317,sepal_width#1318,petal_length#1319,petal_width#1320,species#1321] csv
#          :- Relation [sepal_length#1327,sepal_width#1328,petal_length#1329,petal_width#1330,species#1331] csv
#          :- Relation [sepal_length#1337,sepal_width#1338,petal_length#1339,petal_width#1340,species#1341] csv
#          :- Relation [sepal_length#1347,sepal_width#1348,petal_length#1349,petal_width#1350,species#1351] csv
#          :- Relation [sepal_length#1357,sepal_width#1358,petal_length#1359,petal_width#1360,species#1361] csv
#          :- Relation [sepal_length#1367,sepal_width#1368,petal_length#1369,petal_width#1370,species#1371] csv
#          :- Relation [sepal_length#1377,sepal_width#1378,petal_length#1379,petal_width#1380,species#1381] csv
#          :- Relation [sepal_length#1387,sepal_width#1388,petal_length#1389,petal_width#1390,species#1391] csv
#          :- Relation [sepal_length#1397,sepal_width#1398,petal_length#1399,petal_width#1400,species#1401] csv
#          :- Relation [sepal_length#1407,sepal_width#1408,petal_length#1409,petal_width#1410,species#1411] csv
#          :- Relation [sepal_length#1417,sepal_width#1418,petal_length#1419,petal_width#1420,species#1421] csv
#          :- Relation [sepal_length#1427,sepal_width#1428,petal_length#1429,petal_width#1430,species#1431] csv
#          :- Relation [sepal_length#1437,sepal_width#1438,petal_length#1439,petal_width#1440,species#1441] csv
#          :- Relation [sepal_length#1447,sepal_width#1448,petal_length#1449,petal_width#1450,species#1451] csv
#          :- Relation [sepal_length#1457,sepal_width#1458,petal_length#1459,petal_width#1460,species#1461] csv
#          :- Relation [sepal_length#1467,sepal_width#1468,petal_length#1469,petal_width#1470,species#1471] csv
#          :- Relation [sepal_length#1477,sepal_width#1478,petal_length#1479,petal_width#1480,species#1481] csv
#          :- Relation [sepal_length#1487,sepal_width#1488,petal_length#1489,petal_width#1490,species#1491] csv
#          :- Relation [sepal_length#1497,sepal_width#1498,petal_length#1499,petal_width#1500,species#1501] csv
#          :- Relation [sepal_length#1507,sepal_width#1508,petal_length#1509,petal_width#1510,species#1511] csv
#          :- Relation [sepal_length#1517,sepal_width#1518,petal_length#1519,petal_width#1520,species#1521] csv
#          :- Relation [sepal_length#1527,sepal_width#1528,petal_length#1529,petal_width#1530,species#1531] csv
#          :- Relation [sepal_length#1537,sepal_width#1538,petal_length#1539,petal_width#1540,species#1541] csv
#          :- Relation [sepal_length#1547,sepal_width#1548,petal_length#1549,petal_width#1550,species#1551] csv
#          :- Relation [sepal_length#1557,sepal_width#1558,petal_length#1559,petal_width#1560,species#1561] csv
#          :- Relation [sepal_length#1567,sepal_width#1568,petal_length#1569,petal_width#1570,species#1571] csv
#          :- Relation [sepal_length#1577,sepal_width#1578,petal_length#1579,petal_width#1580,species#1581] csv
#          :- Relation [sepal_length#1587,sepal_width#1588,petal_length#1589,petal_width#1590,species#1591] csv
#          :- Relation [sepal_length#1597,sepal_width#1598,petal_length#1599,petal_width#1600,species#1601] csv
#          :- Relation [sepal_length#1607,sepal_width#1608,petal_length#1609,petal_width#1610,species#1611] csv
#          :- Relation [sepal_length#1617,sepal_width#1618,petal_length#1619,petal_width#1620,species#1621] csv
#          :- Relation [sepal_length#1627,sepal_width#1628,petal_length#1629,petal_width#1630,species#1631] csv
#          :- Relation [sepal_length#1637,sepal_width#1638,petal_length#1639,petal_width#1640,species#1641] csv
#          :- Relation [sepal_length#1647,sepal_width#1648,petal_length#1649,petal_width#1650,species#1651] csv
#          :- Relation [sepal_length#1657,sepal_width#1658,petal_length#1659,petal_width#1660,species#1661] csv
#          :- Relation [sepal_length#1667,sepal_width#1668,petal_length#1669,petal_width#1670,species#1671] csv
#          :- Relation [sepal_length#1677,sepal_width#1678,petal_length#1679,petal_width#1680,species#1681] csv
#          :- Relation [sepal_length#1687,sepal_width#1688,petal_length#1689,petal_width#1690,species#1691] csv
#          :- Relation [sepal_length#1697,sepal_width#1698,petal_length#1699,petal_width#1700,species#1701] csv
#          :- Relation [sepal_length#1707,sepal_width#1708,petal_length#1709,petal_width#1710,species#1711] csv
#          :- Relation [sepal_length#1717,sepal_width#1718,petal_length#1719,petal_width#1720,species#1721] csv
#          :- Relation [sepal_length#1727,sepal_width#1728,petal_length#1729,petal_width#1730,species#1731] csv
#          :- Relation [sepal_length#1737,sepal_width#1738,petal_length#1739,petal_width#1740,species#1741] csv
#          :- Relation [sepal_length#1747,sepal_width#1748,petal_length#1749,petal_width#1750,species#1751] csv
#          :- Relation [sepal_length#1757,sepal_width#1758,petal_length#1759,petal_width#1760,species#1761] csv
#          :- Relation [sepal_length#1767,sepal_width#1768,petal_length#1769,petal_width#1770,species#1771] csv
#          :- Relation [sepal_length#1777,sepal_width#1778,petal_length#1779,petal_width#1780,species#1781] csv
#          :- Relation [sepal_length#1787,sepal_width#1788,petal_length#1789,petal_width#1790,species#1791] csv
#          :- Relation [sepal_length#1797,sepal_width#1798,petal_length#1799,petal_width#1800,species#1801] csv
#          :- Relation [sepal_length#1807,sepal_width#1808,petal_length#1809,petal_width#1810,species#1811] csv
#          :- Relation [sepal_length#1817,sepal_width#1818,petal_length#1819,petal_width#1820,species#1821] csv
#          :- Relation [sepal_length#1827,sepal_width#1828,petal_length#1829,petal_width#1830,species#1831] csv
#          :- Relation [sepal_length#1837,sepal_width#1838,petal_length#1839,petal_width#1840,species#1841] csv
#          :- Relation [sepal_length#1847,sepal_width#1848,petal_length#1849,petal_width#1850,species#1851] csv
#          :- Relation [sepal_length#1857,sepal_width#1858,petal_length#1859,petal_width#1860,species#1861] csv
#          :- Relation [sepal_length#1867,sepal_width#1868,petal_length#1869,petal_width#1870,species#1871] csv
#          :- Relation [sepal_length#1877,sepal_width#1878,petal_length#1879,petal_width#1880,species#1881] csv
#          :- Relation [sepal_length#1887,sepal_width#1888,petal_length#1889,petal_width#1890,species#1891] csv
#          :- Relation [sepal_length#1897,sepal_width#1898,petal_length#1899,petal_width#1900,species#1901] csv
#          :- Relation [sepal_length#1907,sepal_width#1908,petal_length#1909,petal_width#1910,species#1911] csv
#          :- Relation [sepal_length#1917,sepal_width#1918,petal_length#1919,petal_width#1920,species#1921] csv
#          :- Relation [sepal_length#1927,sepal_width#1928,petal_length#1929,petal_width#1930,species#1931] csv
#          :- Relation [sepal_length#1937,sepal_width#1938,petal_length#1939,petal_width#1940,species#1941] csv
#          :- Relation [sepal_length#1947,sepal_width#1948,petal_length#1949,petal_width#1950,species#1951] csv
#          :- Relation [sepal_length#1957,sepal_width#1958,petal_length#1959,petal_width#1960,species#1961] csv
#          :- Relation [sepal_length#1967,sepal_width#1968,petal_length#1969,petal_width#1970,species#1971] csv
#          :- Relation [sepal_length#1977,sepal_width#1978,petal_length#1979,petal_width#1980,species#1981] csv
#          :- Relation [sepal_length#1987,sepal_width#1988,petal_length#1989,petal_width#1990,species#1991] csv
#          :- Relation [sepal_length#1997,sepal_width#1998,petal_length#1999,petal_width#2000,species#2001] csv
#          +- Relation [sepal_length#2007,sepal_width#2008,petal_length#2009,petal_width#2010,species#2011] csv
#
# == Analyzed Logical Plan ==
# species: string, cnt: bigint, avg_sepal_len: double
# Aggregate [species#21], [species#21, count(1) AS cnt#6328L, avg(sepal_length#17) AS avg_sepal_len#6330]
# +- Repartition 4, false
#    +- Repartition 16, true
#       +- Union false, false
#          :- Relation [sepal_length#17,sepal_width#18,petal_length#19,petal_width#20,species#21] csv
#          :- Relation [sepal_length#27,sepal_width#28,petal_length#29,petal_width#30,species#31] csv
#          :- Relation [sepal_length#37,sepal_width#38,petal_length#39,petal_width#40,species#41] csv
#          :- Relation [sepal_length#47,sepal_width#48,petal_length#49,petal_width#50,species#51] csv
#          :- Relation [sepal_length#57,sepal_width#58,petal_length#59,petal_width#60,species#61] csv
#          :- Relation [sepal_length#67,sepal_width#68,petal_length#69,petal_width#70,species#71] csv
#          :- Relation [sepal_length#77,sepal_width#78,petal_length#79,petal_width#80,species#81] csv
#          :- Relation [sepal_length#87,sepal_width#88,petal_length#89,petal_width#90,species#91] csv
#          :- Relation [sepal_length#97,sepal_width#98,petal_length#99,petal_width#100,species#101] csv
#          :- Relation [sepal_length#107,sepal_width#108,petal_length#109,petal_width#110,species#111] csv
#          :- Relation [sepal_length#117,sepal_width#118,petal_length#119,petal_width#120,species#121] csv
#          :- Relation [sepal_length#127,sepal_width#128,petal_length#129,petal_width#130,species#131] csv
#          :- Relation [sepal_length#137,sepal_width#138,petal_length#139,petal_width#140,species#141] csv
#          :- Relation [sepal_length#147,sepal_width#148,petal_length#149,petal_width#150,species#151] csv
#          :- Relation [sepal_length#157,sepal_width#158,petal_length#159,petal_width#160,species#161] csv
#          :- Relation [sepal_length#167,sepal_width#168,petal_length#169,petal_width#170,species#171] csv
#          :- Relation [sepal_length#177,sepal_width#178,petal_length#179,petal_width#180,species#181] csv
#          :- Relation [sepal_length#187,sepal_width#188,petal_length#189,petal_width#190,species#191] csv
#          :- Relation [sepal_length#197,sepal_width#198,petal_length#199,petal_width#200,species#201] csv
#          :- Relation [sepal_length#207,sepal_width#208,petal_length#209,petal_width#210,species#211] csv
#          :- Relation [sepal_length#217,sepal_width#218,petal_length#219,petal_width#220,species#221] csv
#          :- Relation [sepal_length#227,sepal_width#228,petal_length#229,petal_width#230,species#231] csv
#          :- Relation [sepal_length#237,sepal_width#238,petal_length#239,petal_width#240,species#241] csv
#          :- Relation [sepal_length#247,sepal_width#248,petal_length#249,petal_width#250,species#251] csv
#          :- Relation [sepal_length#257,sepal_width#258,petal_length#259,petal_width#260,species#261] csv
#          :- Relation [sepal_length#267,sepal_width#268,petal_length#269,petal_width#270,species#271] csv
#          :- Relation [sepal_length#277,sepal_width#278,petal_length#279,petal_width#280,species#281] csv
#          :- Relation [sepal_length#287,sepal_width#288,petal_length#289,petal_width#290,species#291] csv
#          :- Relation [sepal_length#297,sepal_width#298,petal_length#299,petal_width#300,species#301] csv
#          :- Relation [sepal_length#307,sepal_width#308,petal_length#309,petal_width#310,species#311] csv
#          :- Relation [sepal_length#317,sepal_width#318,petal_length#319,petal_width#320,species#321] csv
#          :- Relation [sepal_length#327,sepal_width#328,petal_length#329,petal_width#330,species#331] csv
#          :- Relation [sepal_length#337,sepal_width#338,petal_length#339,petal_width#340,species#341] csv
#          :- Relation [sepal_length#347,sepal_width#348,petal_length#349,petal_width#350,species#351] csv
#          :- Relation [sepal_length#357,sepal_width#358,petal_length#359,petal_width#360,species#361] csv
#          :- Relation [sepal_length#367,sepal_width#368,petal_length#369,petal_width#370,species#371] csv
#          :- Relation [sepal_length#377,sepal_width#378,petal_length#379,petal_width#380,species#381] csv
#          :- Relation [sepal_length#387,sepal_width#388,petal_length#389,petal_width#390,species#391] csv
#          :- Relation [sepal_length#397,sepal_width#398,petal_length#399,petal_width#400,species#401] csv
#          :- Relation [sepal_length#407,sepal_width#408,petal_length#409,petal_width#410,species#411] csv
#          :- Relation [sepal_length#417,sepal_width#418,petal_length#419,petal_width#420,species#421] csv
#          :- Relation [sepal_length#427,sepal_width#428,petal_length#429,petal_width#430,species#431] csv
#          :- Relation [sepal_length#437,sepal_width#438,petal_length#439,petal_width#440,species#441] csv
#          :- Relation [sepal_length#447,sepal_width#448,petal_length#449,petal_width#450,species#451] csv
#          :- Relation [sepal_length#457,sepal_width#458,petal_length#459,petal_width#460,species#461] csv
#          :- Relation [sepal_length#467,sepal_width#468,petal_length#469,petal_width#470,species#471] csv
#          :- Relation [sepal_length#477,sepal_width#478,petal_length#479,petal_width#480,species#481] csv
#          :- Relation [sepal_length#487,sepal_width#488,petal_length#489,petal_width#490,species#491] csv
#          :- Relation [sepal_length#497,sepal_width#498,petal_length#499,petal_width#500,species#501] csv
#          :- Relation [sepal_length#507,sepal_width#508,petal_length#509,petal_width#510,species#511] csv
#          :- Relation [sepal_length#517,sepal_width#518,petal_length#519,petal_width#520,species#521] csv
#          :- Relation [sepal_length#527,sepal_width#528,petal_length#529,petal_width#530,species#531] csv
#          :- Relation [sepal_length#537,sepal_width#538,petal_length#539,petal_width#540,species#541] csv
#          :- Relation [sepal_length#547,sepal_width#548,petal_length#549,petal_width#550,species#551] csv
#          :- Relation [sepal_length#557,sepal_width#558,petal_length#559,petal_width#560,species#561] csv
#          :- Relation [sepal_length#567,sepal_width#568,petal_length#569,petal_width#570,species#571] csv
#          :- Relation [sepal_length#577,sepal_width#578,petal_length#579,petal_width#580,species#581] csv
#          :- Relation [sepal_length#587,sepal_width#588,petal_length#589,petal_width#590,species#591] csv
#          :- Relation [sepal_length#597,sepal_width#598,petal_length#599,petal_width#600,species#601] csv
#          :- Relation [sepal_length#607,sepal_width#608,petal_length#609,petal_width#610,species#611] csv
#          :- Relation [sepal_length#617,sepal_width#618,petal_length#619,petal_width#620,species#621] csv
#          :- Relation [sepal_length#627,sepal_width#628,petal_length#629,petal_width#630,species#631] csv
#          :- Relation [sepal_length#637,sepal_width#638,petal_length#639,petal_width#640,species#641] csv
#          :- Relation [sepal_length#647,sepal_width#648,petal_length#649,petal_width#650,species#651] csv
#          :- Relation [sepal_length#657,sepal_width#658,petal_length#659,petal_width#660,species#661] csv
#          :- Relation [sepal_length#667,sepal_width#668,petal_length#669,petal_width#670,species#671] csv
#          :- Relation [sepal_length#677,sepal_width#678,petal_length#679,petal_width#680,species#681] csv
#          :- Relation [sepal_length#687,sepal_width#688,petal_length#689,petal_width#690,species#691] csv
#          :- Relation [sepal_length#697,sepal_width#698,petal_length#699,petal_width#700,species#701] csv
#          :- Relation [sepal_length#707,sepal_width#708,petal_length#709,petal_width#710,species#711] csv
#          :- Relation [sepal_length#717,sepal_width#718,petal_length#719,petal_width#720,species#721] csv
#          :- Relation [sepal_length#727,sepal_width#728,petal_length#729,petal_width#730,species#731] csv
#          :- Relation [sepal_length#737,sepal_width#738,petal_length#739,petal_width#740,species#741] csv
#          :- Relation [sepal_length#747,sepal_width#748,petal_length#749,petal_width#750,species#751] csv
#          :- Relation [sepal_length#757,sepal_width#758,petal_length#759,petal_width#760,species#761] csv
#          :- Relation [sepal_length#767,sepal_width#768,petal_length#769,petal_width#770,species#771] csv
#          :- Relation [sepal_length#777,sepal_width#778,petal_length#779,petal_width#780,species#781] csv
#          :- Relation [sepal_length#787,sepal_width#788,petal_length#789,petal_width#790,species#791] csv
#          :- Relation [sepal_length#797,sepal_width#798,petal_length#799,petal_width#800,species#801] csv
#          :- Relation [sepal_length#807,sepal_width#808,petal_length#809,petal_width#810,species#811] csv
#          :- Relation [sepal_length#817,sepal_width#818,petal_length#819,petal_width#820,species#821] csv
#          :- Relation [sepal_length#827,sepal_width#828,petal_length#829,petal_width#830,species#831] csv
#          :- Relation [sepal_length#837,sepal_width#838,petal_length#839,petal_width#840,species#841] csv
#          :- Relation [sepal_length#847,sepal_width#848,petal_length#849,petal_width#850,species#851] csv
#          :- Relation [sepal_length#857,sepal_width#858,petal_length#859,petal_width#860,species#861] csv
#          :- Relation [sepal_length#867,sepal_width#868,petal_length#869,petal_width#870,species#871] csv
#          :- Relation [sepal_length#877,sepal_width#878,petal_length#879,petal_width#880,species#881] csv
#          :- Relation [sepal_length#887,sepal_width#888,petal_length#889,petal_width#890,species#891] csv
#          :- Relation [sepal_length#897,sepal_width#898,petal_length#899,petal_width#900,species#901] csv
#          :- Relation [sepal_length#907,sepal_width#908,petal_length#909,petal_width#910,species#911] csv
#          :- Relation [sepal_length#917,sepal_width#918,petal_length#919,petal_width#920,species#921] csv
#          :- Relation [sepal_length#927,sepal_width#928,petal_length#929,petal_width#930,species#931] csv
#          :- Relation [sepal_length#937,sepal_width#938,petal_length#939,petal_width#940,species#941] csv
#          :- Relation [sepal_length#947,sepal_width#948,petal_length#949,petal_width#950,species#951] csv
#          :- Relation [sepal_length#957,sepal_width#958,petal_length#959,petal_width#960,species#961] csv
#          :- Relation [sepal_length#967,sepal_width#968,petal_length#969,petal_width#970,species#971] csv
#          :- Relation [sepal_length#977,sepal_width#978,petal_length#979,petal_width#980,species#981] csv
#          :- Relation [sepal_length#987,sepal_width#988,petal_length#989,petal_width#990,species#991] csv
#          :- Relation [sepal_length#997,sepal_width#998,petal_length#999,petal_width#1000,species#1001] csv
#          :- Relation [sepal_length#1007,sepal_width#1008,petal_length#1009,petal_width#1010,species#1011] csv
#          :- Relation [sepal_length#1017,sepal_width#1018,petal_length#1019,petal_width#1020,species#1021] csv
#          :- Relation [sepal_length#1027,sepal_width#1028,petal_length#1029,petal_width#1030,species#1031] csv
#          :- Relation [sepal_length#1037,sepal_width#1038,petal_length#1039,petal_width#1040,species#1041] csv
#          :- Relation [sepal_length#1047,sepal_width#1048,petal_length#1049,petal_width#1050,species#1051] csv
#          :- Relation [sepal_length#1057,sepal_width#1058,petal_length#1059,petal_width#1060,species#1061] csv
#          :- Relation [sepal_length#1067,sepal_width#1068,petal_length#1069,petal_width#1070,species#1071] csv
#          :- Relation [sepal_length#1077,sepal_width#1078,petal_length#1079,petal_width#1080,species#1081] csv
#          :- Relation [sepal_length#1087,sepal_width#1088,petal_length#1089,petal_width#1090,species#1091] csv
#          :- Relation [sepal_length#1097,sepal_width#1098,petal_length#1099,petal_width#1100,species#1101] csv
#          :- Relation [sepal_length#1107,sepal_width#1108,petal_length#1109,petal_width#1110,species#1111] csv
#          :- Relation [sepal_length#1117,sepal_width#1118,petal_length#1119,petal_width#1120,species#1121] csv
#          :- Relation [sepal_length#1127,sepal_width#1128,petal_length#1129,petal_width#1130,species#1131] csv
#          :- Relation [sepal_length#1137,sepal_width#1138,petal_length#1139,petal_width#1140,species#1141] csv
#          :- Relation [sepal_length#1147,sepal_width#1148,petal_length#1149,petal_width#1150,species#1151] csv
#          :- Relation [sepal_length#1157,sepal_width#1158,petal_length#1159,petal_width#1160,species#1161] csv
#          :- Relation [sepal_length#1167,sepal_width#1168,petal_length#1169,petal_width#1170,species#1171] csv
#          :- Relation [sepal_length#1177,sepal_width#1178,petal_length#1179,petal_width#1180,species#1181] csv
#          :- Relation [sepal_length#1187,sepal_width#1188,petal_length#1189,petal_width#1190,species#1191] csv
#          :- Relation [sepal_length#1197,sepal_width#1198,petal_length#1199,petal_width#1200,species#1201] csv
#          :- Relation [sepal_length#1207,sepal_width#1208,petal_length#1209,petal_width#1210,species#1211] csv
#          :- Relation [sepal_length#1217,sepal_width#1218,petal_length#1219,petal_width#1220,species#1221] csv
#          :- Relation [sepal_length#1227,sepal_width#1228,petal_length#1229,petal_width#1230,species#1231] csv
#          :- Relation [sepal_length#1237,sepal_width#1238,petal_length#1239,petal_width#1240,species#1241] csv
#          :- Relation [sepal_length#1247,sepal_width#1248,petal_length#1249,petal_width#1250,species#1251] csv
#          :- Relation [sepal_length#1257,sepal_width#1258,petal_length#1259,petal_width#1260,species#1261] csv
#          :- Relation [sepal_length#1267,sepal_width#1268,petal_length#1269,petal_width#1270,species#1271] csv
#          :- Relation [sepal_length#1277,sepal_width#1278,petal_length#1279,petal_width#1280,species#1281] csv
#          :- Relation [sepal_length#1287,sepal_width#1288,petal_length#1289,petal_width#1290,species#1291] csv
#          :- Relation [sepal_length#1297,sepal_width#1298,petal_length#1299,petal_width#1300,species#1301] csv
#          :- Relation [sepal_length#1307,sepal_width#1308,petal_length#1309,petal_width#1310,species#1311] csv
#          :- Relation [sepal_length#1317,sepal_width#1318,petal_length#1319,petal_width#1320,species#1321] csv
#          :- Relation [sepal_length#1327,sepal_width#1328,petal_length#1329,petal_width#1330,species#1331] csv
#          :- Relation [sepal_length#1337,sepal_width#1338,petal_length#1339,petal_width#1340,species#1341] csv
#          :- Relation [sepal_length#1347,sepal_width#1348,petal_length#1349,petal_width#1350,species#1351] csv
#          :- Relation [sepal_length#1357,sepal_width#1358,petal_length#1359,petal_width#1360,species#1361] csv
#          :- Relation [sepal_length#1367,sepal_width#1368,petal_length#1369,petal_width#1370,species#1371] csv
#          :- Relation [sepal_length#1377,sepal_width#1378,petal_length#1379,petal_width#1380,species#1381] csv
#          :- Relation [sepal_length#1387,sepal_width#1388,petal_length#1389,petal_width#1390,species#1391] csv
#          :- Relation [sepal_length#1397,sepal_width#1398,petal_length#1399,petal_width#1400,species#1401] csv
#          :- Relation [sepal_length#1407,sepal_width#1408,petal_length#1409,petal_width#1410,species#1411] csv
#          :- Relation [sepal_length#1417,sepal_width#1418,petal_length#1419,petal_width#1420,species#1421] csv
#          :- Relation [sepal_length#1427,sepal_width#1428,petal_length#1429,petal_width#1430,species#1431] csv
#          :- Relation [sepal_length#1437,sepal_width#1438,petal_length#1439,petal_width#1440,species#1441] csv
#          :- Relation [sepal_length#1447,sepal_width#1448,petal_length#1449,petal_width#1450,species#1451] csv
#          :- Relation [sepal_length#1457,sepal_width#1458,petal_length#1459,petal_width#1460,species#1461] csv
#          :- Relation [sepal_length#1467,sepal_width#1468,petal_length#1469,petal_width#1470,species#1471] csv
#          :- Relation [sepal_length#1477,sepal_width#1478,petal_length#1479,petal_width#1480,species#1481] csv
#          :- Relation [sepal_length#1487,sepal_width#1488,petal_length#1489,petal_width#1490,species#1491] csv
#          :- Relation [sepal_length#1497,sepal_width#1498,petal_length#1499,petal_width#1500,species#1501] csv
#          :- Relation [sepal_length#1507,sepal_width#1508,petal_length#1509,petal_width#1510,species#1511] csv
#          :- Relation [sepal_length#1517,sepal_width#1518,petal_length#1519,petal_width#1520,species#1521] csv
#          :- Relation [sepal_length#1527,sepal_width#1528,petal_length#1529,petal_width#1530,species#1531] csv
#          :- Relation [sepal_length#1537,sepal_width#1538,petal_length#1539,petal_width#1540,species#1541] csv
#          :- Relation [sepal_length#1547,sepal_width#1548,petal_length#1549,petal_width#1550,species#1551] csv
#          :- Relation [sepal_length#1557,sepal_width#1558,petal_length#1559,petal_width#1560,species#1561] csv
#          :- Relation [sepal_length#1567,sepal_width#1568,petal_length#1569,petal_width#1570,species#1571] csv
#          :- Relation [sepal_length#1577,sepal_width#1578,petal_length#1579,petal_width#1580,species#1581] csv
#          :- Relation [sepal_length#1587,sepal_width#1588,petal_length#1589,petal_width#1590,species#1591] csv
#          :- Relation [sepal_length#1597,sepal_width#1598,petal_length#1599,petal_width#1600,species#1601] csv
#          :- Relation [sepal_length#1607,sepal_width#1608,petal_length#1609,petal_width#1610,species#1611] csv
#          :- Relation [sepal_length#1617,sepal_width#1618,petal_length#1619,petal_width#1620,species#1621] csv
#          :- Relation [sepal_length#1627,sepal_width#1628,petal_length#1629,petal_width#1630,species#1631] csv
#          :- Relation [sepal_length#1637,sepal_width#1638,petal_length#1639,petal_width#1640,species#1641] csv
#          :- Relation [sepal_length#1647,sepal_width#1648,petal_length#1649,petal_width#1650,species#1651] csv
#          :- Relation [sepal_length#1657,sepal_width#1658,petal_length#1659,petal_width#1660,species#1661] csv
#          :- Relation [sepal_length#1667,sepal_width#1668,petal_length#1669,petal_width#1670,species#1671] csv
#          :- Relation [sepal_length#1677,sepal_width#1678,petal_length#1679,petal_width#1680,species#1681] csv
#          :- Relation [sepal_length#1687,sepal_width#1688,petal_length#1689,petal_width#1690,species#1691] csv
#          :- Relation [sepal_length#1697,sepal_width#1698,petal_length#1699,petal_width#1700,species#1701] csv
#          :- Relation [sepal_length#1707,sepal_width#1708,petal_length#1709,petal_width#1710,species#1711] csv
#          :- Relation [sepal_length#1717,sepal_width#1718,petal_length#1719,petal_width#1720,species#1721] csv
#          :- Relation [sepal_length#1727,sepal_width#1728,petal_length#1729,petal_width#1730,species#1731] csv
#          :- Relation [sepal_length#1737,sepal_width#1738,petal_length#1739,petal_width#1740,species#1741] csv
#          :- Relation [sepal_length#1747,sepal_width#1748,petal_length#1749,petal_width#1750,species#1751] csv
#          :- Relation [sepal_length#1757,sepal_width#1758,petal_length#1759,petal_width#1760,species#1761] csv
#          :- Relation [sepal_length#1767,sepal_width#1768,petal_length#1769,petal_width#1770,species#1771] csv
#          :- Relation [sepal_length#1777,sepal_width#1778,petal_length#1779,petal_width#1780,species#1781] csv
#          :- Relation [sepal_length#1787,sepal_width#1788,petal_length#1789,petal_width#1790,species#1791] csv
#          :- Relation [sepal_length#1797,sepal_width#1798,petal_length#1799,petal_width#1800,species#1801] csv
#          :- Relation [sepal_length#1807,sepal_width#1808,petal_length#1809,petal_width#1810,species#1811] csv
#          :- Relation [sepal_length#1817,sepal_width#1818,petal_length#1819,petal_width#1820,species#1821] csv
#          :- Relation [sepal_length#1827,sepal_width#1828,petal_length#1829,petal_width#1830,species#1831] csv
#          :- Relation [sepal_length#1837,sepal_width#1838,petal_length#1839,petal_width#1840,species#1841] csv
#          :- Relation [sepal_length#1847,sepal_width#1848,petal_length#1849,petal_width#1850,species#1851] csv
#          :- Relation [sepal_length#1857,sepal_width#1858,petal_length#1859,petal_width#1860,species#1861] csv
#          :- Relation [sepal_length#1867,sepal_width#1868,petal_length#1869,petal_width#1870,species#1871] csv
#          :- Relation [sepal_length#1877,sepal_width#1878,petal_length#1879,petal_width#1880,species#1881] csv
#          :- Relation [sepal_length#1887,sepal_width#1888,petal_length#1889,petal_width#1890,species#1891] csv
#          :- Relation [sepal_length#1897,sepal_width#1898,petal_length#1899,petal_width#1900,species#1901] csv
#          :- Relation [sepal_length#1907,sepal_width#1908,petal_length#1909,petal_width#1910,species#1911] csv
#          :- Relation [sepal_length#1917,sepal_width#1918,petal_length#1919,petal_width#1920,species#1921] csv
#          :- Relation [sepal_length#1927,sepal_width#1928,petal_length#1929,petal_width#1930,species#1931] csv
#          :- Relation [sepal_length#1937,sepal_width#1938,petal_length#1939,petal_width#1940,species#1941] csv
#          :- Relation [sepal_length#1947,sepal_width#1948,petal_length#1949,petal_width#1950,species#1951] csv
#          :- Relation [sepal_length#1957,sepal_width#1958,petal_length#1959,petal_width#1960,species#1961] csv
#          :- Relation [sepal_length#1967,sepal_width#1968,petal_length#1969,petal_width#1970,species#1971] csv
#          :- Relation [sepal_length#1977,sepal_width#1978,petal_length#1979,petal_width#1980,species#1981] csv
#          :- Relation [sepal_length#1987,sepal_width#1988,petal_length#1989,petal_width#1990,species#1991] csv
#          :- Relation [sepal_length#1997,sepal_width#1998,petal_length#1999,petal_width#2000,species#2001] csv
#          +- Relation [sepal_length#2007,sepal_width#2008,petal_length#2009,petal_width#2010,species#2011] csv
#
# == Optimized Logical Plan ==
# Aggregate [species#21], [species#21, count(1) AS cnt#6328L, avg(sepal_length#17) AS avg_sepal_len#6330]
# +- Project [sepal_length#17, species#21]
#    +- InMemoryRelation [sepal_length#17, sepal_width#18, petal_length#19, petal_width#20, species#21], StorageLevel(disk, memory, deserialized, 1 replicas)
#          +- AdaptiveSparkPlan isFinalPlan=true
#             +- == Final Plan ==
#                Coalesce 4
#                +- ShuffleQueryStage 0
#                   +- Exchange RoundRobinPartitioning(16), REPARTITION_BY_NUM, [plan_id=4693]
#                      +- Union
#                         :- FileScan csv [sepal_length#17,sepal_width#18,petal_length#19,petal_width#20,species#21] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#27,sepal_width#28,petal_length#29,petal_width#30,species#31] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#37,sepal_width#38,petal_length#39,petal_width#40,species#41] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#47,sepal_width#48,petal_length#49,petal_width#50,species#51] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#57,sepal_width#58,petal_length#59,petal_width#60,species#61] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#67,sepal_width#68,petal_length#69,petal_width#70,species#71] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                         :- FileScan csv [sepal_length#77,sepal_width#78,petal_length#79,petal_width#80,species#81] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
# ...
#                                  :- FileScan csv [sepal_length#1657,sepal_width#1658,petal_length#1659,petal_width#1660,species#1661] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1667,sepal_width#1668,petal_length#1669,petal_width#1670,species#1671] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1677,sepal_width#1678,petal_length#1679,petal_width#1680,species#1681] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1687,sepal_width#1688,petal_length#1689,petal_width#1690,species#1691] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1697,sepal_width#1698,petal_length#1699,petal_width#1700,species#1701] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1707,sepal_width#1708,petal_length#1709,petal_width#1710,species#1711] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1717,sepal_width#1718,petal_length#1719,petal_width#1720,species#1721] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1727,sepal_width#1728,petal_length#1729,petal_width#1730,species#1731] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1737,sepal_width#1738,petal_length#1739,petal_width#1740,species#1741] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1747,sepal_width#1748,petal_length#1749,petal_width#1750,species#1751] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1757,sepal_width#1758,petal_length#1759,petal_width#1760,species#1761] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1767,sepal_width#1768,petal_length#1769,petal_width#1770,species#1771] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1777,sepal_width#1778,petal_length#1779,petal_width#1780,species#1781] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1787,sepal_width#1788,petal_length#1789,petal_width#1790,species#1791] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1797,sepal_width#1798,petal_length#1799,petal_width#1800,species#1801] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1807,sepal_width#1808,petal_length#1809,petal_width#1810,species#1811] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1817,sepal_width#1818,petal_length#1819,petal_width#1820,species#1821] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1827,sepal_width#1828,petal_length#1829,petal_width#1830,species#1831] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1837,sepal_width#1838,petal_length#1839,petal_width#1840,species#1841] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1847,sepal_width#1848,petal_length#1849,petal_width#1850,species#1851] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1857,sepal_width#1858,petal_length#1859,petal_width#1860,species#1861] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1867,sepal_width#1868,petal_length#1869,petal_width#1870,species#1871] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1877,sepal_width#1878,petal_length#1879,petal_width#1880,species#1881] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1887,sepal_width#1888,petal_length#1889,petal_width#1890,species#1891] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1897,sepal_width#1898,petal_length#1899,petal_width#1900,species#1901] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1907,sepal_width#1908,petal_length#1909,petal_width#1910,species#1911] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1917,sepal_width#1918,petal_length#1919,petal_width#1920,species#1921] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1927,sepal_width#1928,petal_length#1929,petal_width#1930,species#1931] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1937,sepal_width#1938,petal_length#1939,petal_width#1940,species#1941] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1947,sepal_width#1948,petal_length#1949,petal_width#1950,species#1951] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1957,sepal_width#1958,petal_length#1959,petal_width#1960,species#1961] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1967,sepal_width#1968,petal_length#1969,petal_width#1970,species#1971] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1977,sepal_width#1978,petal_length#1979,petal_width#1980,species#1981] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1987,sepal_width#1988,petal_length#1989,petal_width#1990,species#1991] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  :- FileScan csv [sepal_length#1997,sepal_width#1998,petal_length#1999,petal_width#2000,species#2001] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#                                  +- FileScan csv [sepal_length#2007,sepal_width#2008,petal_length#2009,petal_width#2010,species#2011] Batched: false, DataFilters: [], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/tmp/iris.csv], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,species:string>
#       +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false]),false), [plan_id=5031]
#          +- Filter isnotnull(species#6415)
#             +- Scan ExistingRDD[species#6415,description#6416]
#
#
# ------------------------------------------------------------
# Skew mitigation pattern: add 'salt' to keys to spread large-key loads across partitions.
# Example (not executed heavy):
#
# # pseudo:
# from pyspark.sql.functions import floor, rand
# N = 10  # number of salts
# big_salted = big_coalesce.withColumn('salt', floor(rand() * N))
# small_salted = small_df.withColumn('salt', F.lit(0))  # or replicate small_df for salt range
# # join on both key and salt
#
# ------------------------------------------------------------
# Writing partitioned parquet to output/iris_parquet_partitioned (this will create one folder per species)
# Read back with predicate pushdown - only scans partition setosa
# Explain plan for filtered read (should show PartitionFilters):
# == Physical Plan ==
# *(1) ColumnarToRow
# +- FileScan parquet [sepal_length#6609,sepal_width#6610,petal_length#6611,petal_width#6612,description#6613,species#6614] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/debabratapati/Documents/pyspark/my_pyspark_course/research..., PartitionFilters: [isnotnull(species#6614), (species#6614 = setosa)], PushedFilters: [], ReadSchema: struct<sepal_length:double,sepal_width:double,petal_length:double,petal_width:double,description:...
#
#
# Subset count (should be small): 10000
# ------------------------------------------------------------
# Checkpoint done. Partitions: 4
# ------------------------------------------------------------
# Done. Spark stopped.

# %% [markdown]
# Core concepts (short & practical)
#
# Partitions — Spark splits data into partitions. Operations run per-partition in parallel. Too few partitions → underutilized CPU; too many → overhead.
#
# Check partitions: df.rdd.getNumPartitions() or df.rdd.getNumPartitions() for RDDs.
#
# Change partitions: repartition(n) (full shuffle), coalesce(n) (no shuffle, only decrease).
#
# Shuffle — expensive distributed data movement (caused by groupBy, join, repartition, aggregations). Minimize shuffle where possible.
#
# Caching / Persisting — store intermediate DataFrames in memory/disk to avoid recomputation. Use df.cache() / df.persist(StorageLevel.MEMORY_AND_DISK) and df.unpersist() when done.
#
# Broadcast Join — small table broadcast to all executors avoids shuffle for join. Use broadcast(small_df) from pyspark.sql.functions or spark.conf.set("spark.sql.autoBroadcastJoinThreshold", size).
#
# File format & layout — Parquet (columnar, compressed) is preferred for analytics. Partition files by columns for predicate pushdown; beware small-files problem.
#
# Predicate pushdown & projection pruning — Spark will read only necessary columns/partitions for Parquet/ORC; design queries to benefit.
#
# Skew — uneven key distribution hurts groupBy/join. Use salting, broadcast, or split heavy keys.
#
# Explain & UI — df.explain(True) for extended planner + physical plan. Use Spark UI (localhost:4040 in local mode) to inspect stages, tasks, and shuffles.
#
# Memory & configs — tune spark.executor.memory, spark.driver.memory, spark.sql.shuffle.partitions (default often 200 — too high for local); set appropriate values for cluster.
#
# Bucketing — for repeated joins on same keys, bucketing (native to Spark SQL) can reduce shuffle.
